# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df2 = pd.read_csv('food_coded.csv')
df2 = df2[['GPA', 'Gender' , 'calories_chicken', 'turkey_calories', 'income', 'employment', 'father_education', 'mother_education', 'grade_level', 'eating_out', 'on_off_campus', 'weight', 'cook','cuisine', 'exercise', 'drink','breakfast', 'parents_cook', 'pay_meal_out', 'nutritional_check']]

# %%
# making variable of the % correct. we could not find the other actual calorie counts of others
df2['calories_chicken_prop'] = df2['calories_chicken']/720
df2['calories_turkey_prop'] = df2['turkey_calories']/690

# %%
# Clean GPA 
df2['GPA'] = df2['GPA'].str[:3]
df2['GPA'].replace(['Per','Unk'], None, inplace=True)
df2['GPA'].value_counts()
df2['GPA'] = df2['GPA'].astype(float)

# %%
# Gender, calories_chicken, turkey_calories, income, employment, father_education, mother_education, on_off_campus, are clean

# %%
# Clean weight 
df2['weight'] = df2['weight'].str.extract('(\d+)').astype(float)

# %% [markdown]
# ## What type of students are more likely to eat out?
# Frequency of eating out vs:
# - income
# - job status (employed/not employed)
# - living situation (on-off campus)
# - parents cook
# - grade
# - willingness to pay for a meal out
# - nutritional check
# - exercising

# %%
def eatout_groupby_plot(variable, title, xlabel):
    d = df2.groupby([variable, 'eating_out']).count().unstack()['GPA']
    d.columns= ['Never', '1-2 times', '2-3 times', '3-5 times', 'Everyday' ]
    d.plot.bar()
    plt.title(title)
    plt.xlabel(xlabel)

# %%
corr_columns = df2[['GPA','income','employment','exercise', 'on_off_campus', 'parents_cook', 'grade_level', 'pay_meal_out','nutritional_check', 'eating_out']]
corr_columns.corr()['eating_out'].sort_values(ascending=False)
# Out:
# eating_out           1.000000
# employment           0.170919
# parents_cook         0.152110
# grade_level          0.072972
# on_off_campus        0.043086
# income               0.001340
# nutritional_check   -0.039017
# GPA                 -0.047309
# pay_meal_out        -0.085503
# exercise            -0.095447
# Name: eating_out, dtype: float64

# %% [markdown]
# Based off of these correlations, we would choose to investigate employment, parents_cook, grade_level, on_off_campus, and income. We will also investigate nutritional_check and pay_meal_out because we would assume that these factors would impact someone's willingness to and frequency of eating out.

# %%
eatout_groupby_plot('employment', 'Employment vs Eating Out', 'Employment (1: full time, 2: part time, 3: no)')

# %%
eatout_groupby_plot('parents_cook', 'Parents Cooking vs. Eating Out', 'Parents Cooking (1: almost everyday, 2: 2-3 times per week, 3: 1-2 times per week )')

# %%
eatout_groupby_plot('grade_level', 'Grade vs. Eating Out', 'Grade (1: freshman, 4: senior) ')

# %%
eatout_groupby_plot('on_off_campus', 'Living Situation vs. Eating Out', 'Living Situation (1: on campus, 2: rent, 3: commute, 4: own house)')

# %%
eatout_groupby_plot('income', 'Income vs. Eating Out', 'Income')

# %%
eatout_groupby_plot('nutritional_check', 'Checks Nutrition Fact vs. Eating Out', 'Nutritional Fact Checking (1: never, 2: on certain products only, 3: very rarely, 4: on most products, 5: on everything)')

# %%
eatout_groupby_plot('pay_meal_out', 'Willingness to Pay vs. Eating Out', 'Willingness to Pay (1:>5, 2: 5-10, 3:10-20, 4:20-30, 5:30-40, 6:40+)  ')
